# %%
#Importing the libraries I will need

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing my data

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ct-professor-salaries.csv')

# %%
#Familiarizing myself with the data

# %%
df.head(38)
# Out:
#                                        College  Average All Pay  \
# 0                      Albertus Magnus College            68409
# 1                  Asnuntuck Community College            62190
# 2                    Capital Community College            63225
# 3         Central Connecticut State University            76617
# 4                          Connecticut College            86166
# 5         Eastern Connecticut State University            72819
# 6                         Fairfield University            91926
# 7                    Gateway Community College            69966
# 8                            Hartford Seminary            54387
# 9                  Holy Apostles College & Sem            29331
# 10                Housatonic Community College            55485
# 11                 Lincoln College New England            50733
# 12               LymeAcademy College Fine Arts            33813
# 13                Manchester Community College            67077
# ...

# %%
df.shape
# Out:
# (38, 7)

# %%
df.describe()
# Out:
#        Average All Pay  Average Professor  Associate Professor  \
# count        38.000000          37.000000            37.000000
# mean      73487.605263       89921.918919         69632.756757
# std       20924.994602       28687.833767         16937.611909
# min       29331.000000       32139.000000         32436.000000
# 25%       63285.750000       76995.000000         60183.000000
# 50%       69187.500000       84456.000000         67914.000000
# 75%       78266.250000      105669.000000         79263.000000
# max      144378.000000      192546.000000        117288.000000
#
#        Assistant Professor       Lecturer
# count            35.000000      33.000000
# mean          59753.028571   54280.909091
# std           12185.649271   17485.646786
# min           40095.000000   10647.000000
# 25%           51057.000000   45315.000000
# 50%           56574.000000   51210.000000
# 75%           67680.000000   63000.000000
# max           95499.000000  104697.000000

# %%
#From here I want to get some calculations for each professor type to be able to compare the salaries

# %%
df['Assistant Professor'].median()
# Out:
# 56574.0

# %%
df['Associate Professor'].median()
# Out:
# 67914.0

# %%
#Next I wanted to see the salaries per school per professor type

# %%
df.groupby(['College']) ['Assistant Professor'].median().sort_values(ascending=False)
# Out:
# College
# Yale University                               95499.0
# Wesleyan University                           79209.0
# University of Connecticut                     77373.0
# Trinity College                               76824.0
# US Coast Guard Academy                        75924.0
# Fairfield University                          74133.0
# University of New Haven                       73836.0
# Connecticut College                           69048.0
# Sacred Heart University                       67824.0
# University of Saint Joseph                    67536.0
# Mitchell College                              63180.0
# Quinnipiac University                         62379.0
# University of Hartford                        61920.0
# Western Connecticut State University          61218.0
# Naugatuck Valley Community College            58977.0
# Central Connecticut State University          58544.0
# Southern Connecticut State University         58140.0
# ...

# %%
df.groupby(['College']) ['Associate Professor'].median().sort_values(ascending=False)
# Out:
# College
# Yale University                               117288.0
# Trinity College                                99189.0
# University of Connecticut                      95625.0
# University of New Haven                        93627.0
# Wesleyan University                            93276.0
# Fairfield University                           87516.0
# Sacred Heart University                        83466.0
# Connecticut College                            81639.0
# US Coast Guard Academy                         80388.0
# Quinnipiac University                          79263.0
# University of Saint Joseph                     77058.0
# University of Hartford                         72765.0
# Central Connecticut State University           72387.0
# Southern Connecticut State University          72054.0
# Western Connecticut State University           71955.0
# Post University                                70002.0
# Eastern Connecticut State University           69408.0
# ...

# %%
#From here I want to visualize the information I have gathered

# %%
bargraph = df.plot.bar(x = 'College')

# %% [markdown]
# After reviewing my analysis, I noticed in some instances title does play a part in your salary when becoming a Professor for most Universities/Colleges.
# Becoming a Professor at an Ivy League school such as Yale will yield a higher income, but the same may not be true when compared to other Colleges/Universities. Various factors also can play a role in the salary range such a time working, skillset, etc.
